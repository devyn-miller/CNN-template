# %% [markdown]
# # Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import (
    Dense,
    Flatten,
    Dropout,
    Conv2D,
    MaxPooling2D,
    BatchNormalization,
)
# from keras.optimizers import SGD
from tensorflow.compat.v1.keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %% [markdown]
# # Parameters for Model Training

# %%
batch_size = 128  # Number of samples per gradient update
num_classes = 10  # Total number of classes in the dataset
epochs = 100  # Number of epochs to train the model
data_augmentation = True  # Flag to determine whether to use data augmentation

# %% [markdown]
# # Load and Preprocess the CIFAR-10 Dataset

# %%
(train_x, train_y), (test_x, test_y) = cifar10.load_data()

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_x[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_y[i][0]])
plt.show()

# %%
# Bar chart showing distribution of classes in training set
plt.figure(figsize=(11, 6))
unique, counts = np.unique(train_y, return_counts=True)

plt.bar(unique, counts)
plt.title('Class Frequency')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.xticks(unique, class_names)
plt.show()

# %% [markdown]
# # Preprocess the Data with One-Hot Encoding

# %%
# Convert class vectors to binary class matrices
train_y = to_categorical(train_y, num_classes)
test_y = to_categorical(test_y, num_classes)

# %%
# Normalize pixel values to the range [0, 1]to aid in training convergence
train_x = train_x.astype("float32") / 255.0
test_x = test_x.astype("float32") / 255.0

# %% [markdown]
# # Define the CNN model

# %%
def define_model():
    model = Sequential()
    # First convolutional block with 32 filters, batch normalization, and dropout for regularization
    model.add(
        Conv2D(
            32,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
            input_shape=(32, 32, 3),
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            32,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))

    # Second convolutional block with increased filter size for more complex feature extraction
    model.add(
        Conv2D(
            64,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            64,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))

    # Third convolutional block with further increased filter size
    model.add(
        Conv2D(
            128,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            128,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))

    # Flatten the output from the convolutional layers before passing to the dense layer
    model.add(Flatten())
    # Dense layer for classification
    model.add(Dense(128, activation="relu", kernel_initializer="he_uniform"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    # Output layer with softmax activation for multi-class classification
    model.add(Dense(num_classes, activation="softmax"))

    # Compile the model with legacy SGD optimizer and categorical crossentropy loss function
    optimizer = SGD(learning_rate=0.01)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# # Instantiate and Compile the Model

# %%
model = define_model()

# %% [markdown]
# # Configure Data Augmentation

# %%
if data_augmentation:
    print("Using real-time data augmentation.")
    datagen = ImageDataGenerator(
        width_shift_range=0.1,  # Randomly shift images horizontally
        height_shift_range=0.1,  # Randomly shift images vertically
        horizontal_flip=True,  # Randomly flip images horizontally
    )
    # Compute quantities required for feature-wise normalization
    datagen.fit(train_x)
# Out:
# Using real-time data augmentation.

# %% [markdown]
# # Train the Model

# %%
if not data_augmentation:
    print("Not using data augmentation.")
    history = model.fit(
        train_x,
        train_y,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(test_x, test_y),
        shuffle=True,
    )
else:
    # Fit the model on the batches generated by datagen.flow()
    history = model.fit(
        datagen.flow(train_x, train_y, batch_size=batch_size),
        epochs=epochs,
        validation_data=(test_x, test_y),
        workers=4,
    )
# Out:
# Epoch 1/100
# 391/391 [==============================] - 68s 173ms/step - loss: 2.3834 - accuracy: 0.2625 - val_loss: 1.6041 - val_accuracy: 0.4170
# Epoch 2/100
# 391/391 [==============================] - 63s 162ms/step - loss: 1.7987 - accuracy: 0.3610 - val_loss: 1.4643 - val_accuracy: 0.4630
# Epoch 3/100
# 391/391 [==============================] - 69s 177ms/step - loss: 1.6330 - accuracy: 0.4055 - val_loss: 1.5172 - val_accuracy: 0.4366
# Epoch 4/100
# 391/391 [==============================] - 100s 254ms/step - loss: 1.5440 - accuracy: 0.4351 - val_loss: 1.4196 - val_accuracy: 0.4816
# Epoch 5/100
# 391/391 [==============================] - 108s 276ms/step - loss: 1.4772 - accuracy: 0.4580 - val_loss: 1.4562 - val_accuracy: 0.4667
# Epoch 6/100
# 391/391 [==============================] - 81s 208ms/step - loss: 1.4262 - accuracy: 0.4790 - val_loss: 1.4161 - val_accuracy: 0.4865
# Epoch 7/100
# 391/391 [==============================] - 82s 210ms/step - loss: 1.3850 - accuracy: 0.4976 - val_loss: 1.3748 - val_accuracy: 0.4957
# Epoch 8/100
# 391/391 [==============================] - 85s 217ms/step - loss: 1.3488 - accuracy: 0.5083 - val_loss: 1.3809 - val_accuracy: 0.4980
# Epoch 9/100
# 391/391 [==============================] - 82s 209ms/step - loss: 1.3152 - accuracy: 0.5223 - val_loss: 1.3360 - val_accuracy: 0.5172
# Epoch 10/100
# 391/391 [==============================] - 83s 211ms/step - loss: 1.2861 - accuracy: 0.5366 - val_loss: 1.2816 - val_accuracy: 0.5331
# Epoch 11/100
# 391/391 [==============================] - 81s 206ms/step - loss: 1.2525 - accuracy: 0.5484 - val_loss: 1.2247 - val_accuracy: 0.5607
# Epoch 12/100
# 391/391 [==============================] - 81s 207ms/step - loss: 1.2279 - accuracy: 0.5567 - val_loss: 1.2399 - val_accuracy: 0.5555
# Epoch 13/100
# 391/391 [==============================] - 86s 221ms/step - loss: 1.2058 - accuracy: 0.5674 - val_loss: 1.3404 - val_accuracy: 0.5253
# Epoch 14/100
# 391/391 [==============================] - 81s 207ms/step - loss: 1.1839 - accuracy: 0.5744 - val_loss: 1.2082 - val_accuracy: 0.5664
# Epoch 15/100
# 391/391 [==============================] - 80s 204ms/step - loss: 1.1591 - accuracy: 0.5853 - val_loss: 1.3084 - val_accuracy: 0.5309
# Epoch 16/100
# 391/391 [==============================] - 81s 206ms/step - loss: 1.1366 - accuracy: 0.5943 - val_loss: 1.1260 - val_accuracy: 0.5999
# Epoch 17/100
# 391/391 [==============================] - 82s 209ms/step - loss: 1.1212 - accuracy: 0.5986 - val_loss: 1.2297 - val_accuracy: 0.5663
# Epoch 18/100
# 391/391 [==============================] - 80s 204ms/step - loss: 1.1065 - accuracy: 0.6044 - val_loss: 1.1296 - val_accuracy: 0.6000
# Epoch 19/100
# 391/391 [==============================] - 79s 203ms/step - loss: 1.0850 - accuracy: 0.6155 - val_loss: 1.0095 - val_accuracy: 0.6393
# Epoch 20/100
# 391/391 [==============================] - 80s 204ms/step - loss: 1.0717 - accuracy: 0.6171 - val_loss: 1.1312 - val_accuracy: 0.5956
# Epoch 21/100
# 391/391 [==============================] - 80s 204ms/step - loss: 1.0577 - accuracy: 0.6213 - val_loss: 1.1111 - val_accuracy: 0.6048
# Epoch 22/100
# 391/391 [==============================] - 80s 203ms/step - loss: 1.0412 - accuracy: 0.6280 - val_loss: 1.1039 - val_accuracy: 0.6129
# Epoch 23/100
# 391/391 [==============================] - 80s 204ms/step - loss: 1.0273 - accuracy: 0.6347 - val_loss: 0.9957 - val_accuracy: 0.6451
# Epoch 24/100
# 391/391 [==============================] - 80s 205ms/step - loss: 1.0153 - accuracy: 0.6379 - val_loss: 1.0564 - val_accuracy: 0.6247
# Epoch 25/100
# 391/391 [==============================] - 79s 202ms/step - loss: 1.0035 - accuracy: 0.6446 - val_loss: 0.9931 - val_accuracy: 0.6485
# Epoch 26/100
# 391/391 [==============================] - 80s 205ms/step - loss: 0.9902 - accuracy: 0.6494 - val_loss: 1.0699 - val_accuracy: 0.6197
# Epoch 27/100
# 391/391 [==============================] - 81s 206ms/step - loss: 0.9840 - accuracy: 0.6508 - val_loss: 1.0389 - val_accuracy: 0.6357
# Epoch 28/100
# 391/391 [==============================] - 80s 203ms/step - loss: 0.9747 - accuracy: 0.6521 - val_loss: 0.9125 - val_accuracy: 0.6720
# Epoch 29/100
# 391/391 [==============================] - 82s 209ms/step - loss: 0.9605 - accuracy: 0.6599 - val_loss: 1.0023 - val_accuracy: 0.6444
# Epoch 30/100
# 391/391 [==============================] - 81s 207ms/step - loss: 0.9535 - accuracy: 0.6606 - val_loss: 0.9478 - val_accuracy: 0.6612
# Epoch 31/100
# 391/391 [==============================] - 83s 211ms/step - loss: 0.9448 - accuracy: 0.6666 - val_loss: 0.8945 - val_accuracy: 0.6773
# Epoch 32/100
# 391/391 [==============================] - 81s 208ms/step - loss: 0.9374 - accuracy: 0.6686 - val_loss: 0.8708 - val_accuracy: 0.6903
# Epoch 33/100
# 391/391 [==============================] - 82s 208ms/step - loss: 0.9302 - accuracy: 0.6718 - val_loss: 0.9192 - val_accuracy: 0.6708
# Epoch 34/100
# 391/391 [==============================] - 81s 207ms/step - loss: 0.9158 - accuracy: 0.6752 - val_loss: 0.9690 - val_accuracy: 0.6584
# Epoch 35/100
# 391/391 [==============================] - 82s 210ms/step - loss: 0.9070 - accuracy: 0.6796 - val_loss: 0.9300 - val_accuracy: 0.6679
# Epoch 36/100
# 391/391 [==============================] - 81s 206ms/step - loss: 0.9079 - accuracy: 0.6790 - val_loss: 0.9703 - val_accuracy: 0.6594
# Epoch 37/100
# 391/391 [==============================] - 79s 201ms/step - loss: 0.8945 - accuracy: 0.6839 - val_loss: 0.8274 - val_accuracy: 0.7065
# Epoch 38/100
# 391/391 [==============================] - 74s 190ms/step - loss: 0.8886 - accuracy: 0.6866 - val_loss: 0.8763 - val_accuracy: 0.6846
# Epoch 39/100
# 391/391 [==============================] - 72s 184ms/step - loss: 0.8804 - accuracy: 0.6885 - val_loss: 0.8981 - val_accuracy: 0.6805
# Epoch 40/100
# 391/391 [==============================] - 73s 186ms/step - loss: 0.8808 - accuracy: 0.6903 - val_loss: 0.9116 - val_accuracy: 0.6778
# Epoch 41/100
# 391/391 [==============================] - 72s 185ms/step - loss: 0.8686 - accuracy: 0.6916 - val_loss: 0.9065 - val_accuracy: 0.6763
# Epoch 42/100
# 391/391 [==============================] - 71s 181ms/step - loss: 0.8708 - accuracy: 0.6941 - val_loss: 0.8960 - val_accuracy: 0.6853
# Epoch 43/100
# 391/391 [==============================] - 76s 195ms/step - loss: 0.8571 - accuracy: 0.6992 - val_loss: 0.8806 - val_accuracy: 0.6958
# Epoch 44/100
# 391/391 [==============================] - 71s 182ms/step - loss: 0.8540 - accuracy: 0.7006 - val_loss: 0.8590 - val_accuracy: 0.6975
# Epoch 45/100
# 391/391 [==============================] - 73s 187ms/step - loss: 0.8506 - accuracy: 0.7008 - val_loss: 0.8941 - val_accuracy: 0.6842
# Epoch 46/100
# 391/391 [==============================] - 73s 186ms/step - loss: 0.8426 - accuracy: 0.7014 - val_loss: 0.8759 - val_accuracy: 0.6932
# Epoch 47/100
# 391/391 [==============================] - 78s 199ms/step - loss: 0.8388 - accuracy: 0.7055 - val_loss: 0.8273 - val_accuracy: 0.7055
# Epoch 48/100
# 391/391 [==============================] - 90s 230ms/step - loss: 0.8306 - accuracy: 0.7096 - val_loss: 0.7926 - val_accuracy: 0.7200
# Epoch 49/100
# 391/391 [==============================] - 79s 201ms/step - loss: 0.8240 - accuracy: 0.7098 - val_loss: 0.8127 - val_accuracy: 0.7109
# Epoch 50/100
# 391/391 [==============================] - 78s 200ms/step - loss: 0.8259 - accuracy: 0.7088 - val_loss: 0.8221 - val_accuracy: 0.7092
# Epoch 51/100
# 391/391 [==============================] - 78s 199ms/step - loss: 0.8187 - accuracy: 0.7130 - val_loss: 0.7947 - val_accuracy: 0.7229
# Epoch 52/100
# 391/391 [==============================] - 80s 203ms/step - loss: 0.8113 - accuracy: 0.7133 - val_loss: 0.7415 - val_accuracy: 0.7355
# Epoch 53/100
# 391/391 [==============================] - 82s 208ms/step - loss: 0.8041 - accuracy: 0.7160 - val_loss: 0.7981 - val_accuracy: 0.7215
# Epoch 54/100
# 391/391 [==============================] - 88s 224ms/step - loss: 0.8013 - accuracy: 0.7184 - val_loss: 0.8481 - val_accuracy: 0.7015
# Epoch 55/100
# 391/391 [==============================] - 81s 207ms/step - loss: 0.8019 - accuracy: 0.7189 - val_loss: 0.7528 - val_accuracy: 0.7341
# Epoch 56/100
# 391/391 [==============================] - 91s 232ms/step - loss: 0.7874 - accuracy: 0.7229 - val_loss: 0.7972 - val_accuracy: 0.7223
# Epoch 57/100
# 391/391 [==============================] - 81s 207ms/step - loss: 0.7848 - accuracy: 0.7251 - val_loss: 0.7420 - val_accuracy: 0.7357
# Epoch 58/100
# 391/391 [==============================] - 81s 206ms/step - loss: 0.7858 - accuracy: 0.7264 - val_loss: 0.7737 - val_accuracy: 0.7242
# Epoch 59/100
# 391/391 [==============================] - 80s 205ms/step - loss: 0.7781 - accuracy: 0.7267 - val_loss: 0.7978 - val_accuracy: 0.7198
# Epoch 60/100
# 391/391 [==============================] - 81s 208ms/step - loss: 0.7739 - accuracy: 0.7273 - val_loss: 0.7769 - val_accuracy: 0.7286
# Epoch 61/100
# 391/391 [==============================] - 82s 208ms/step - loss: 0.7748 - accuracy: 0.7274 - val_loss: 0.7219 - val_accuracy: 0.7476
# Epoch 62/100
# 391/391 [==============================] - 81s 207ms/step - loss: 0.7717 - accuracy: 0.7305 - val_loss: 0.8154 - val_accuracy: 0.7178
# Epoch 63/100
# 391/391 [==============================] - 81s 208ms/step - loss: 0.7637 - accuracy: 0.7341 - val_loss: 0.7034 - val_accuracy: 0.7539
# Epoch 64/100
# 391/391 [==============================] - 81s 207ms/step - loss: 0.7641 - accuracy: 0.7335 - val_loss: 0.7433 - val_accuracy: 0.7380
# Epoch 65/100
# 391/391 [==============================] - 80s 205ms/step - loss: 0.7609 - accuracy: 0.7340 - val_loss: 0.7469 - val_accuracy: 0.7350
# Epoch 66/100
# 391/391 [==============================] - 82s 208ms/step - loss: 0.7557 - accuracy: 0.7347 - val_loss: 0.7991 - val_accuracy: 0.7220
# Epoch 67/100
# 391/391 [==============================] - 80s 204ms/step - loss: 0.7550 - accuracy: 0.7353 - val_loss: 0.7680 - val_accuracy: 0.7339
# Epoch 68/100
# 391/391 [==============================] - 80s 205ms/step - loss: 0.7447 - accuracy: 0.7389 - val_loss: 0.7560 - val_accuracy: 0.7319
# Epoch 69/100
# 391/391 [==============================] - 79s 203ms/step - loss: 0.7393 - accuracy: 0.7392 - val_loss: 0.7928 - val_accuracy: 0.7217
# Epoch 70/100
# 391/391 [==============================] - 80s 204ms/step - loss: 0.7391 - accuracy: 0.7407 - val_loss: 0.6994 - val_accuracy: 0.7542
# Epoch 71/100
# 391/391 [==============================] - 80s 205ms/step - loss: 0.7372 - accuracy: 0.7428 - val_loss: 0.8048 - val_accuracy: 0.7183
# Epoch 72/100
# 391/391 [==============================] - 81s 207ms/step - loss: 0.7314 - accuracy: 0.7448 - val_loss: 0.7215 - val_accuracy: 0.7463
# Epoch 73/100
# 391/391 [==============================] - 80s 205ms/step - loss: 0.7231 - accuracy: 0.7484 - val_loss: 0.7100 - val_accuracy: 0.7515
# Epoch 74/100
# 391/391 [==============================] - 80s 203ms/step - loss: 0.7270 - accuracy: 0.7456 - val_loss: 0.7890 - val_accuracy: 0.7259
# Epoch 75/100
# 391/391 [==============================] - 80s 205ms/step - loss: 0.7284 - accuracy: 0.7474 - val_loss: 0.7339 - val_accuracy: 0.7486
# Epoch 76/100
# 391/391 [==============================] - 81s 207ms/step - loss: 0.7209 - accuracy: 0.7471 - val_loss: 0.7654 - val_accuracy: 0.7350
# Epoch 77/100
# 391/391 [==============================] - 78s 198ms/step - loss: 0.7212 - accuracy: 0.7497 - val_loss: 0.7609 - val_accuracy: 0.7364
# Epoch 78/100
# 391/391 [==============================] - 80s 203ms/step - loss: 0.7135 - accuracy: 0.7511 - val_loss: 0.6941 - val_accuracy: 0.7543
# Epoch 79/100
# 391/391 [==============================] - 79s 201ms/step - loss: 0.7109 - accuracy: 0.7513 - val_loss: 0.6484 - val_accuracy: 0.7705
# Epoch 80/100
# 391/391 [==============================] - 78s 198ms/step - loss: 0.7060 - accuracy: 0.7534 - val_loss: 0.7348 - val_accuracy: 0.7447
# Epoch 81/100
# 391/391 [==============================] - 79s 201ms/step - loss: 0.7112 - accuracy: 0.7513 - val_loss: 0.6708 - val_accuracy: 0.7648
# Epoch 82/100
# 391/391 [==============================] - 80s 204ms/step - loss: 0.7046 - accuracy: 0.7544 - val_loss: 0.6881 - val_accuracy: 0.7594
# Epoch 83/100
# 391/391 [==============================] - 79s 202ms/step - loss: 0.7048 - accuracy: 0.7533 - val_loss: 0.6688 - val_accuracy: 0.7663
# Epoch 84/100
# 391/391 [==============================] - 80s 203ms/step - loss: 0.6956 - accuracy: 0.7570 - val_loss: 0.6870 - val_accuracy: 0.7642
# Epoch 85/100
# 391/391 [==============================] - 79s 200ms/step - loss: 0.6929 - accuracy: 0.7576 - val_loss: 0.6756 - val_accuracy: 0.7643
# Epoch 86/100
# 391/391 [==============================] - 80s 204ms/step - loss: 0.6930 - accuracy: 0.7597 - val_loss: 0.6612 - val_accuracy: 0.7672
# Epoch 87/100
# 391/391 [==============================] - 78s 199ms/step - loss: 0.6899 - accuracy: 0.7580 - val_loss: 0.6550 - val_accuracy: 0.7697
# Epoch 88/100
# 391/391 [==============================] - 79s 201ms/step - loss: 0.6845 - accuracy: 0.7608 - val_loss: 0.6990 - val_accuracy: 0.7533
# Epoch 89/100
# 391/391 [==============================] - 79s 201ms/step - loss: 0.6847 - accuracy: 0.7625 - val_loss: 0.6610 - val_accuracy: 0.7685
# Epoch 90/100
# 391/391 [==============================] - 79s 201ms/step - loss: 0.6800 - accuracy: 0.7618 - val_loss: 0.6748 - val_accuracy: 0.7619
# Epoch 91/100
# 391/391 [==============================] - 79s 203ms/step - loss: 0.6756 - accuracy: 0.7668 - val_loss: 0.6641 - val_accuracy: 0.7658
# Epoch 92/100
# 391/391 [==============================] - 79s 201ms/step - loss: 0.6729 - accuracy: 0.7636 - val_loss: 0.6577 - val_accuracy: 0.7738
# Epoch 93/100
# 391/391 [==============================] - 81s 208ms/step - loss: 0.6718 - accuracy: 0.7658 - val_loss: 0.6676 - val_accuracy: 0.7692
# Epoch 94/100
# 391/391 [==============================] - 80s 204ms/step - loss: 0.6658 - accuracy: 0.7704 - val_loss: 0.6443 - val_accuracy: 0.7749
# Epoch 95/100
# 391/391 [==============================] - 79s 201ms/step - loss: 0.6632 - accuracy: 0.7715 - val_loss: 0.6409 - val_accuracy: 0.7753
# Epoch 96/100
# 391/391 [==============================] - 81s 208ms/step - loss: 0.6618 - accuracy: 0.7696 - val_loss: 0.6969 - val_accuracy: 0.7593
# Epoch 97/100
# 391/391 [==============================] - 81s 208ms/step - loss: 0.6549 - accuracy: 0.7726 - val_loss: 0.6099 - val_accuracy: 0.7889
# Epoch 98/100
# 391/391 [==============================] - 83s 213ms/step - loss: 0.6603 - accuracy: 0.7686 - val_loss: 0.6482 - val_accuracy: 0.7743
# Epoch 99/100
# 391/391 [==============================] - 80s 204ms/step - loss: 0.6599 - accuracy: 0.7706 - val_loss: 0.6662 - val_accuracy: 0.7689
# Epoch 100/100
# 391/391 [==============================] - 79s 203ms/step - loss: 0.6532 - accuracy: 0.7735 - val_loss: 0.6246 - val_accuracy: 0.7814

# %% [markdown]
# # Evaluate the Model's Performance on the Test Set

# %%
scores = model.evaluate(test_x, test_y, verbose=1)
print("Test loss:", scores[0])
print("Test accuracy:", scores[1])
# Out:
# 313/313 [==============================] - 7s 22ms/step - loss: 0.6246 - accuracy: 0.7814
# Test loss: 0.6246429681777954
# Test accuracy: 0.7814000248908997

# %% [markdown]
# # Generate Predictions for Test Set

# %%
predictions = model.predict(test_x)
# Out:
# 313/313 [==============================] - 8s 23ms/step

# %% [markdown]
# # Generate a Confusion Matrix and Classification Report to Evaluate the Model's Performance

# %%
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(test_y, axis=1)
cm = confusion_matrix(true_classes, predicted_classes)
print("Confusion Matrix")
print(cm)
print("Classification Report")
print(classification_report(true_classes, predicted_classes, target_names=class_names))
# Out:
# Confusion Matrix
# [[811  12  30  11  26   1  23   4  64  18]
#  [  8 920   0   3   1   0  14   0  16  38]
#  [ 61   4 620  23  61  46 160  17   4   4]
#  [ 10   5  44 530  50 111 205  16  16  13]
#  [ 12   1  29  18 746   9 166  15   4   0]
#  [  7   2  38 139  41 638 105  23   4   3]
#  [  3   1   9  11   3   4 965   2   2   0]
#  [ 13   1  25  16  72  32  36 792   3  10]
#  [ 35  14   3   5   2   1  11   1 910  18]
#  [ 23  45   4   3   0   0  13   2  28 882]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Airplane       0.83      0.81      0.82      1000
#   Automobile       0.92      0.92      0.92      1000
#         Bird       0.77      0.62      0.69      1000
#          Cat       0.70      0.53      0.60      1000
#         Deer       0.74      0.75      0.75      1000
#          Dog       0.76      0.64      0.69      1000
#         Frog       0.57      0.96      0.72      1000
#        Horse       0.91      0.79      0.85      1000
#         Ship       0.87      0.91      0.89      1000
#        Truck       0.89      0.88      0.89      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.80      0.78      0.78     10000
# weighted avg       0.80      0.78      0.78     10000

# %% [markdown]
# # Plot Training and Validation Accuracy and Loss to Visualize the Model's Learning Over Time

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="train accuracy")
plt.plot(history.history["val_accuracy"], label="validation accuracy")
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="train loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()

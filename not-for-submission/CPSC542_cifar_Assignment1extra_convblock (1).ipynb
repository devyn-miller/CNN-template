# %% [markdown]
# # Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import (
    Dense,
    Flatten,
    Dropout,
    Conv2D,
    MaxPooling2D,
    BatchNormalization,
)
# from keras.optimizers import SGD
from tensorflow.compat.v1.keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %% [markdown]
# # Parameters for Model Training

# %%
batch_size = 32  # Number of samples per gradient update
num_classes = 10  # Total number of classes in the dataset
epochs = 100  # Number of epochs to train the model
data_augmentation = True  # Flag to determine whether to use data augmentation

# %% [markdown]
# # Load and Preprocess the CIFAR-10 Dataset

# %%
(train_x, train_y), (test_x, test_y) = cifar10.load_data()

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_x[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_y[i][0]])
plt.show()

# %%
# Bar chart showing distribution of classes in training set
plt.figure(figsize=(11, 6))
unique, counts = np.unique(train_y, return_counts=True)

plt.bar(unique, counts)
plt.title('Class Frequency')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.xticks(unique, class_names)
plt.show()

# %% [markdown]
# # Preprocess the Data with One-Hot Encoding

# %%
# Convert class vectors to binary class matrices
train_y = to_categorical(train_y, num_classes)
test_y = to_categorical(test_y, num_classes)

# %%
# Normalize pixel values to the range [0, 1]to aid in training convergence
train_x = train_x.astype("float32") / 255.0
test_x = test_x.astype("float32") / 255.0

# %% [markdown]
# # Define the CNN model

# %%
def define_model():
    model = Sequential()
    # First convolutional block with 32 filters, batch normalization, and dropout for regularization
    model.add(
        Conv2D(
            32,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
            input_shape=(32, 32, 3),
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            32,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))

    # Second convolutional block with increased filter size for more complex feature extraction
    model.add(
        Conv2D(
            64,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            64,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))

    # Third convolutional block with further increased filter size
    model.add(
        Conv2D(
            128,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            128,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))

    # Fourth convolutional block with further increased filter size
    model.add(
        Conv2D(
            256,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            256,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.5))

    # Flatten the output from the convolutional layers before passing to the dense layer
    model.add(Flatten())
    # Dense layer for classification
    model.add(Dense(256, activation="relu", kernel_initializer="he_uniform"))
    model.add(BatchNormalization())
    model.add(Dropout(0.6))
    # Output layer with softmax activation for multi-class classification
    model.add(Dense(num_classes, activation="softmax"))

    # Compile the model with legacy SGD optimizer and categorical crossentropy loss function
    optimizer = SGD(learning_rate=0.01)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# # Instantiate and Compile the Model

# %%
model = define_model()

# %% [markdown]
# # Configure Data Augmentation

# %%
if data_augmentation:
    print("Using real-time data augmentation.")
    datagen = ImageDataGenerator(
        width_shift_range=0.1,  # Randomly shift images horizontally
        height_shift_range=0.1,  # Randomly shift images vertically
        horizontal_flip=True,  # Randomly flip images horizontally
    )
    # Compute quantities required for feature-wise normalization
    datagen.fit(train_x)
# Out:
# Using real-time data augmentation.

# %% [markdown]
# # Train the Model

# %%
if not data_augmentation:
    print("Not using data augmentation.")
    history = model.fit(
        train_x,
        train_y,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(test_x, test_y),
        shuffle=True,
    )
else:
    # Fit the model on the batches generated by datagen.flow()
    history = model.fit(
        datagen.flow(train_x, train_y, batch_size=batch_size),
        epochs=epochs,
        validation_data=(test_x, test_y),
        workers=4,
    )
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 133s 85ms/step - loss: 2.1118 - accuracy: 0.2817 - val_loss: 1.7818 - val_accuracy: 0.3460
# Epoch 2/100
# 1563/1563 [==============================] - 138s 88ms/step - loss: 1.6421 - accuracy: 0.3880 - val_loss: 1.6199 - val_accuracy: 0.4019
# Epoch 3/100
# 1563/1563 [==============================] - 141s 90ms/step - loss: 1.5228 - accuracy: 0.4380 - val_loss: 1.6536 - val_accuracy: 0.3976
# Epoch 4/100
# 1563/1563 [==============================] - 136s 87ms/step - loss: 1.4324 - accuracy: 0.4718 - val_loss: 1.4906 - val_accuracy: 0.4502
# Epoch 5/100
# 1563/1563 [==============================] - 131s 84ms/step - loss: 1.3496 - accuracy: 0.5111 - val_loss: 1.4127 - val_accuracy: 0.5099
# Epoch 6/100
# 1563/1563 [==============================] - 133s 85ms/step - loss: 1.2815 - accuracy: 0.5366 - val_loss: 1.2746 - val_accuracy: 0.5509
# Epoch 7/100
# 1563/1563 [==============================] - 137s 88ms/step - loss: 1.2346 - accuracy: 0.5573 - val_loss: 1.1396 - val_accuracy: 0.5914
# Epoch 8/100
# 1563/1563 [==============================] - 133s 85ms/step - loss: 1.1883 - accuracy: 0.5749 - val_loss: 1.3019 - val_accuracy: 0.5646
# Epoch 9/100
# 1563/1563 [==============================] - 131s 84ms/step - loss: 1.1530 - accuracy: 0.5882 - val_loss: 1.1461 - val_accuracy: 0.5990
# Epoch 10/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 1.1207 - accuracy: 0.6012 - val_loss: 1.1867 - val_accuracy: 0.5895
# Epoch 11/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 1.0781 - accuracy: 0.6164 - val_loss: 1.0639 - val_accuracy: 0.6245
# Epoch 12/100
# 1563/1563 [==============================] - 131s 84ms/step - loss: 1.0561 - accuracy: 0.6257 - val_loss: 1.0966 - val_accuracy: 0.6142
# Epoch 13/100
# 1563/1563 [==============================] - 131s 84ms/step - loss: 1.0158 - accuracy: 0.6421 - val_loss: 1.0734 - val_accuracy: 0.6278
# Epoch 14/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.9901 - accuracy: 0.6502 - val_loss: 0.9086 - val_accuracy: 0.6789
# Epoch 15/100
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.9674 - accuracy: 0.6597 - val_loss: 0.9080 - val_accuracy: 0.6856
# Epoch 16/100
# 1563/1563 [==============================] - 131s 84ms/step - loss: 0.9423 - accuracy: 0.6703 - val_loss: 0.8395 - val_accuracy: 0.7031
# Epoch 17/100
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.9173 - accuracy: 0.6801 - val_loss: 1.0203 - val_accuracy: 0.6614
# Epoch 18/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.8959 - accuracy: 0.6884 - val_loss: 0.8719 - val_accuracy: 0.6936
# Epoch 19/100
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.8751 - accuracy: 0.6935 - val_loss: 0.8077 - val_accuracy: 0.7169
# Epoch 20/100
# 1563/1563 [==============================] - 147s 94ms/step - loss: 0.8618 - accuracy: 0.7016 - val_loss: 0.8916 - val_accuracy: 0.6963
# Epoch 21/100
# 1563/1563 [==============================] - 171s 109ms/step - loss: 0.8474 - accuracy: 0.7096 - val_loss: 0.7802 - val_accuracy: 0.7308
# Epoch 22/100
# 1563/1563 [==============================] - 138s 88ms/step - loss: 0.8346 - accuracy: 0.7105 - val_loss: 0.8034 - val_accuracy: 0.7248
# Epoch 23/100
# 1563/1563 [==============================] - 157s 100ms/step - loss: 0.8186 - accuracy: 0.7175 - val_loss: 0.8040 - val_accuracy: 0.7210
# Epoch 24/100
# 1563/1563 [==============================] - 153s 98ms/step - loss: 0.8023 - accuracy: 0.7226 - val_loss: 0.7435 - val_accuracy: 0.7491
# Epoch 25/100
# 1563/1563 [==============================] - 146s 94ms/step - loss: 0.7989 - accuracy: 0.7222 - val_loss: 0.7626 - val_accuracy: 0.7390
# Epoch 26/100
# 1563/1563 [==============================] - 137s 88ms/step - loss: 0.7754 - accuracy: 0.7335 - val_loss: 0.6289 - val_accuracy: 0.7805
# Epoch 27/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.7718 - accuracy: 0.7358 - val_loss: 0.7399 - val_accuracy: 0.7488
# Epoch 28/100
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.7597 - accuracy: 0.7394 - val_loss: 0.6798 - val_accuracy: 0.7704
# Epoch 29/100
# 1563/1563 [==============================] - 129s 83ms/step - loss: 0.7529 - accuracy: 0.7434 - val_loss: 0.6940 - val_accuracy: 0.7626
# Epoch 30/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.7400 - accuracy: 0.7467 - val_loss: 0.6883 - val_accuracy: 0.7672
# Epoch 31/100
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.7235 - accuracy: 0.7521 - val_loss: 0.6788 - val_accuracy: 0.7729
# Epoch 32/100
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.7184 - accuracy: 0.7560 - val_loss: 0.6424 - val_accuracy: 0.7826
# Epoch 33/100
# 1563/1563 [==============================] - 143s 92ms/step - loss: 0.7098 - accuracy: 0.7569 - val_loss: 0.7144 - val_accuracy: 0.7632
# Epoch 34/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.7008 - accuracy: 0.7613 - val_loss: 0.6083 - val_accuracy: 0.7953
# Epoch 35/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.6944 - accuracy: 0.7631 - val_loss: 0.6114 - val_accuracy: 0.7941
# Epoch 36/100
# 1563/1563 [==============================] - 131s 84ms/step - loss: 0.6990 - accuracy: 0.7631 - val_loss: 0.6828 - val_accuracy: 0.7686
# Epoch 37/100
# 1563/1563 [==============================] - 129s 82ms/step - loss: 0.6800 - accuracy: 0.7676 - val_loss: 0.5702 - val_accuracy: 0.8063
# Epoch 38/100
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.6788 - accuracy: 0.7683 - val_loss: 0.5968 - val_accuracy: 0.8008
# Epoch 39/100
# 1563/1563 [==============================] - 131s 84ms/step - loss: 0.6675 - accuracy: 0.7737 - val_loss: 0.5890 - val_accuracy: 0.8029
# Epoch 40/100
# 1563/1563 [==============================] - 140s 89ms/step - loss: 0.6610 - accuracy: 0.7752 - val_loss: 0.5996 - val_accuracy: 0.7970
# Epoch 41/100
#  232/1563 [===>..........................] - ETA: 1:54 - loss: 0.6499 - accuracy: 0.7757

# %% [markdown]
# # Evaluate the Model's Performance on the Test Set

# %%
scores = model.evaluate(test_x, test_y, verbose=1)
print("Test loss:", scores[0])
print("Test accuracy:", scores[1])
# Out:
# 313/313 [==============================] - 4s 14ms/step - loss: 0.4216 - accuracy: 0.8576
# Test loss: 0.4216468632221222
# Test accuracy: 0.8575999736785889

# %% [markdown]
# # Generate Predictions for Test Set

# %%
predictions = model.predict(test_x)
# Out:
# 313/313 [==============================] - 5s 15ms/step

# %% [markdown]
# # Generate a Confusion Matrix and Classification Report to Evaluate the Model's Performance

# %%
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(test_y, axis=1)
cm = confusion_matrix(true_classes, predicted_classes)
print("Confusion Matrix")
print(cm)
print("Classification Report")
print(classification_report(true_classes, predicted_classes, target_names=class_names))
# Out:
# Confusion Matrix
# [[898  20  17   3   5   0   4   6  29  18]
#  [  5 951   0   1   0   0   3   0   4  36]
#  [ 55   3 756  24  43  18  67  21   5   8]
#  [ 18   9  31 678  54  60  89  32  11  18]
#  [  9   3  21  11 848   6  58  41   3   0]
#  [ 10   4  21 121  39 711  41  44   3   6]
#  [  3   3  11   8   4   1 965   4   1   0]
#  [ 14   0   8  15  26  10   6 916   1   4]
#  [ 36  15   1   2   1   0   5   1 921  18]
#  [ 10  44   1   2   1   0   2   1   7 932]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Airplane       0.85      0.90      0.87      1000
#   Automobile       0.90      0.95      0.93      1000
#         Bird       0.87      0.76      0.81      1000
#          Cat       0.78      0.68      0.73      1000
#         Deer       0.83      0.85      0.84      1000
#          Dog       0.88      0.71      0.79      1000
#         Frog       0.78      0.96      0.86      1000
#        Horse       0.86      0.92      0.89      1000
#         Ship       0.94      0.92      0.93      1000
#        Truck       0.90      0.93      0.91      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000

# %% [markdown]
# # Plot Training and Validation Accuracy and Loss to Visualize the Model's Learning Over Time

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="train accuracy")
plt.plot(history.history["val_accuracy"], label="validation accuracy")
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="train loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()

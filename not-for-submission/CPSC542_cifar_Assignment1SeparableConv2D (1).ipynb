# %% [markdown]
# # Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import (
    Dense,
    Flatten,
    Dropout,
    Conv2D,
    MaxPooling2D,
    BatchNormalization,
)
# from keras.optimizers import SGD
from tensorflow.compat.v1.keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from keras.layers import SeparableConv2D

# %% [markdown]
# # Parameters for Model Training

# %%
batch_size = 32  # Number of samples per gradient update
num_classes = 10  # Total number of classes in the dataset
epochs = 100  # Number of epochs to train the model
data_augmentation = True  # Flag to determine whether to use data augmentation

# %% [markdown]
# # Load and Preprocess the CIFAR-10 Dataset

# %%
(train_x, train_y), (test_x, test_y) = cifar10.load_data()

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_x[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_y[i][0]])
plt.show()

# %%
# Bar chart showing distribution of classes in training set
plt.figure(figsize=(11, 6))
unique, counts = np.unique(train_y, return_counts=True)

plt.bar(unique, counts)
plt.title('Class Frequency')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.xticks(unique, class_names)
plt.show()

# %% [markdown]
# # Preprocess the Data with One-Hot Encoding

# %%
# Convert class vectors to binary class matrices
train_y = to_categorical(train_y, num_classes)
test_y = to_categorical(test_y, num_classes)

# %%
# Normalize pixel values to the range [0, 1]to aid in training convergence
train_x = train_x.astype("float32") / 255.0
test_x = test_x.astype("float32") / 255.0

# %% [markdown]
# # Define the CNN model

# %%
def define_model():
    model = Sequential()
    # First convolutional block with 32 filters, batch normalization, and dropout for regularization
    model.add(
        SeparableConv2D(
            32,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
            input_shape=(32, 32, 3),
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            32,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))

    # Second convolutional block with increased filter size for more complex feature extraction
    model.add(
        SeparableConv2D(
            64,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            64,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))

    # Third convolutional block with further increased filter size
    model.add(
        SeparableConv2D(
            128,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            128,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))

    # Flatten the output from the convolutional layers before passing to the dense layer
    model.add(Flatten())
    # Dense layer for classification
    model.add(Dense(128, activation="relu", kernel_initializer="he_uniform"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    # Output layer with softmax activation for multi-class classification
    model.add(Dense(num_classes, activation="softmax"))

    # Compile the model with legacy SGD optimizer and categorical crossentropy loss function
    optimizer = SGD(learning_rate=0.01)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# # Instantiate and Compile the Model

# %%
model = define_model()

# %% [markdown]
# # Configure Data Augmentation

# %%
if data_augmentation:
    print("Using real-time data augmentation.")
    datagen = ImageDataGenerator(
        width_shift_range=0.1,  # Randomly shift images horizontally
        height_shift_range=0.1,  # Randomly shift images vertically
        horizontal_flip=True,  # Randomly flip images horizontally
    )
    # Compute quantities required for feature-wise normalization
    datagen.fit(train_x)
# Out:
# Using real-time data augmentation.

# %% [markdown]
# # Train the Model

# %%
if not data_augmentation:
    print("Not using data augmentation.")
    history = model.fit(
        train_x,
        train_y,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(test_x, test_y),
        shuffle=True,
    )
else:
    # Fit the model on the batches generated by datagen.flow()
    history = model.fit(
        datagen.flow(train_x, train_y, batch_size=batch_size),
        epochs=epochs,
        validation_data=(test_x, test_y),
        workers=4,
    )
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 178s 114ms/step - loss: 1.9505 - accuracy: 0.3245 - val_loss: 1.4616 - val_accuracy: 0.4616
# Epoch 2/100
# 1563/1563 [==============================] - 146s 93ms/step - loss: 1.5478 - accuracy: 0.4312 - val_loss: 1.3669 - val_accuracy: 0.5036
# Epoch 3/100
# 1563/1563 [==============================] - 149s 96ms/step - loss: 1.4146 - accuracy: 0.4875 - val_loss: 1.6702 - val_accuracy: 0.4039
# Epoch 4/100
# 1563/1563 [==============================] - 147s 94ms/step - loss: 1.3126 - accuracy: 0.5269 - val_loss: 1.5562 - val_accuracy: 0.4711
# Epoch 5/100
# 1563/1563 [==============================] - 140s 90ms/step - loss: 1.2383 - accuracy: 0.5584 - val_loss: 1.0730 - val_accuracy: 0.6213
# Epoch 6/100
# 1563/1563 [==============================] - 137s 88ms/step - loss: 1.1758 - accuracy: 0.5794 - val_loss: 0.9584 - val_accuracy: 0.6620
# Epoch 7/100
# 1563/1563 [==============================] - 141s 90ms/step - loss: 1.1370 - accuracy: 0.5958 - val_loss: 1.0097 - val_accuracy: 0.6486
# Epoch 8/100
# 1563/1563 [==============================] - 144s 92ms/step - loss: 1.0994 - accuracy: 0.6133 - val_loss: 1.0237 - val_accuracy: 0.6449
# Epoch 9/100
# 1563/1563 [==============================] - 146s 93ms/step - loss: 1.0642 - accuracy: 0.6253 - val_loss: 0.9748 - val_accuracy: 0.6541
# Epoch 10/100
# 1563/1563 [==============================] - 143s 91ms/step - loss: 1.0386 - accuracy: 0.6340 - val_loss: 0.8415 - val_accuracy: 0.7026
# Epoch 11/100
# 1563/1563 [==============================] - 140s 90ms/step - loss: 1.0195 - accuracy: 0.6408 - val_loss: 0.9296 - val_accuracy: 0.6781
# Epoch 12/100
# 1563/1563 [==============================] - 142s 91ms/step - loss: 1.0031 - accuracy: 0.6469 - val_loss: 0.8643 - val_accuracy: 0.6972
# Epoch 13/100
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.9804 - accuracy: 0.6569 - val_loss: 0.9690 - val_accuracy: 0.6671
# Epoch 14/100
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.9671 - accuracy: 0.6600 - val_loss: 0.8508 - val_accuracy: 0.6987
# Epoch 15/100
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.9452 - accuracy: 0.6693 - val_loss: 0.9552 - val_accuracy: 0.6711
# Epoch 16/100
# 1563/1563 [==============================] - 147s 94ms/step - loss: 0.9385 - accuracy: 0.6719 - val_loss: 0.7731 - val_accuracy: 0.7322
# Epoch 17/100
# 1563/1563 [==============================] - 146s 93ms/step - loss: 0.9269 - accuracy: 0.6747 - val_loss: 0.8383 - val_accuracy: 0.7058
# Epoch 18/100
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.9129 - accuracy: 0.6829 - val_loss: 0.7670 - val_accuracy: 0.7314
# Epoch 19/100
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.9029 - accuracy: 0.6867 - val_loss: 0.8446 - val_accuracy: 0.7100
# Epoch 20/100
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.8903 - accuracy: 0.6884 - val_loss: 0.7672 - val_accuracy: 0.7324
# Epoch 21/100
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.8827 - accuracy: 0.6943 - val_loss: 0.7565 - val_accuracy: 0.7349
# Epoch 22/100
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.8692 - accuracy: 0.6986 - val_loss: 0.7693 - val_accuracy: 0.7284
# Epoch 23/100
# 1563/1563 [==============================] - 126s 80ms/step - loss: 0.8625 - accuracy: 0.6979 - val_loss: 0.8135 - val_accuracy: 0.7178
# Epoch 24/100
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.8508 - accuracy: 0.7015 - val_loss: 0.7450 - val_accuracy: 0.7407
# Epoch 25/100
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.8505 - accuracy: 0.7047 - val_loss: 0.7755 - val_accuracy: 0.7313
# Epoch 26/100
# 1563/1563 [==============================] - 148s 95ms/step - loss: 0.8347 - accuracy: 0.7111 - val_loss: 0.7152 - val_accuracy: 0.7516
# Epoch 27/100
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.8387 - accuracy: 0.7089 - val_loss: 0.8173 - val_accuracy: 0.7250
# Epoch 28/100
# 1563/1563 [==============================] - 137s 88ms/step - loss: 0.8246 - accuracy: 0.7149 - val_loss: 0.7307 - val_accuracy: 0.7451
# Epoch 29/100
# 1563/1563 [==============================] - 141s 90ms/step - loss: 0.8142 - accuracy: 0.7183 - val_loss: 0.7681 - val_accuracy: 0.7364
# Epoch 30/100
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.8093 - accuracy: 0.7217 - val_loss: 0.7703 - val_accuracy: 0.7309
# Epoch 31/100
# 1563/1563 [==============================] - 145s 93ms/step - loss: 0.7997 - accuracy: 0.7224 - val_loss: 0.7098 - val_accuracy: 0.7541
# Epoch 32/100
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.7953 - accuracy: 0.7244 - val_loss: 0.7207 - val_accuracy: 0.7542
# Epoch 33/100
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.7874 - accuracy: 0.7289 - val_loss: 0.8601 - val_accuracy: 0.7110
# Epoch 34/100
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.7802 - accuracy: 0.7297 - val_loss: 0.6741 - val_accuracy: 0.7681
# Epoch 35/100
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.7819 - accuracy: 0.7290 - val_loss: 0.7216 - val_accuracy: 0.7518
# Epoch 36/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.7765 - accuracy: 0.7327 - val_loss: 0.6619 - val_accuracy: 0.7739
# Epoch 37/100
# 1563/1563 [==============================] - 132s 84ms/step - loss: 0.7632 - accuracy: 0.7361 - val_loss: 0.6588 - val_accuracy: 0.7725
# Epoch 38/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.7597 - accuracy: 0.7382 - val_loss: 0.7101 - val_accuracy: 0.7581
# Epoch 39/100
# 1563/1563 [==============================] - 131s 84ms/step - loss: 0.7539 - accuracy: 0.7432 - val_loss: 0.6233 - val_accuracy: 0.7830
# Epoch 40/100
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.7489 - accuracy: 0.7412 - val_loss: 0.6744 - val_accuracy: 0.7711
# Epoch 41/100
# 1563/1563 [==============================] - 134s 85ms/step - loss: 0.7435 - accuracy: 0.7443 - val_loss: 0.6439 - val_accuracy: 0.7746
# Epoch 42/100
# 1563/1563 [==============================] - 138s 88ms/step - loss: 0.7372 - accuracy: 0.7467 - val_loss: 0.6450 - val_accuracy: 0.7813
# Epoch 43/100
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.7334 - accuracy: 0.7472 - val_loss: 0.7423 - val_accuracy: 0.7425
# Epoch 44/100
# 1563/1563 [==============================] - 131s 84ms/step - loss: 0.7300 - accuracy: 0.7492 - val_loss: 0.5918 - val_accuracy: 0.7964
# Epoch 45/100
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.7301 - accuracy: 0.7493 - val_loss: 0.6635 - val_accuracy: 0.7731
# Epoch 46/100
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.7205 - accuracy: 0.7527 - val_loss: 0.6495 - val_accuracy: 0.7767
# Epoch 47/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.7231 - accuracy: 0.7488 - val_loss: 0.5969 - val_accuracy: 0.7971
# Epoch 48/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.7166 - accuracy: 0.7532 - val_loss: 0.6371 - val_accuracy: 0.7831
# Epoch 49/100
# 1563/1563 [==============================] - 132s 85ms/step - loss: 0.7105 - accuracy: 0.7536 - val_loss: 0.6015 - val_accuracy: 0.7961
# Epoch 50/100
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.7033 - accuracy: 0.7587 - val_loss: 0.6471 - val_accuracy: 0.7833
# Epoch 51/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6975 - accuracy: 0.7590 - val_loss: 0.7947 - val_accuracy: 0.7312
# Epoch 52/100
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.7009 - accuracy: 0.7591 - val_loss: 0.5831 - val_accuracy: 0.8025
# Epoch 53/100
# 1563/1563 [==============================] - 134s 85ms/step - loss: 0.6929 - accuracy: 0.7619 - val_loss: 0.6696 - val_accuracy: 0.7722
# Epoch 54/100
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.6881 - accuracy: 0.7652 - val_loss: 0.6093 - val_accuracy: 0.7930
# Epoch 55/100
# 1563/1563 [==============================] - 134s 86ms/step - loss: 0.6841 - accuracy: 0.7661 - val_loss: 0.5695 - val_accuracy: 0.8067
# Epoch 56/100
# 1563/1563 [==============================] - 135s 87ms/step - loss: 0.6832 - accuracy: 0.7678 - val_loss: 0.6011 - val_accuracy: 0.7982
# Epoch 57/100
# 1563/1563 [==============================] - 134s 85ms/step - loss: 0.6743 - accuracy: 0.7674 - val_loss: 0.5645 - val_accuracy: 0.8069
# Epoch 58/100
# 1563/1563 [==============================] - 78s 50ms/step - loss: 0.6768 - accuracy: 0.7679 - val_loss: 0.6905 - val_accuracy: 0.7671
# Epoch 59/100
# 1563/1563 [==============================] - 692s 443ms/step - loss: 0.6698 - accuracy: 0.7713 - val_loss: 0.6391 - val_accuracy: 0.7850
# Epoch 60/100
# 1563/1563 [==============================] - 737s 472ms/step - loss: 0.6661 - accuracy: 0.7721 - val_loss: 0.5497 - val_accuracy: 0.8131
# Epoch 61/100
# 1563/1563 [==============================] - 559s 358ms/step - loss: 0.6648 - accuracy: 0.7730 - val_loss: 0.5513 - val_accuracy: 0.8142
# Epoch 62/100
# 1563/1563 [==============================] - 1042s 667ms/step - loss: 0.6591 - accuracy: 0.7754 - val_loss: 0.5965 - val_accuracy: 0.7958
# Epoch 63/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 0.6564 - accuracy: 0.7763 - val_loss: 0.5627 - val_accuracy: 0.8090
# Epoch 64/100
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.6512 - accuracy: 0.7780 - val_loss: 0.6071 - val_accuracy: 0.7966
# Epoch 65/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 0.6552 - accuracy: 0.7755 - val_loss: 0.6388 - val_accuracy: 0.7864
# Epoch 66/100
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.6485 - accuracy: 0.7787 - val_loss: 0.5643 - val_accuracy: 0.8072
# Epoch 67/100
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.6466 - accuracy: 0.7797 - val_loss: 0.6621 - val_accuracy: 0.7787
# Epoch 68/100
# 1563/1563 [==============================] - 74s 47ms/step - loss: 0.6470 - accuracy: 0.7807 - val_loss: 0.5292 - val_accuracy: 0.8187
# Epoch 69/100
# 1563/1563 [==============================] - 457s 292ms/step - loss: 0.6387 - accuracy: 0.7818 - val_loss: 0.5629 - val_accuracy: 0.8128
# Epoch 70/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.6375 - accuracy: 0.7819 - val_loss: 0.5309 - val_accuracy: 0.8214
# Epoch 71/100
# 1563/1563 [==============================] - 69s 44ms/step - loss: 0.6311 - accuracy: 0.7840 - val_loss: 0.5206 - val_accuracy: 0.8191
# Epoch 72/100
# 1563/1563 [==============================] - 531s 340ms/step - loss: 0.6338 - accuracy: 0.7839 - val_loss: 0.5164 - val_accuracy: 0.8262
# Epoch 73/100
# 1563/1563 [==============================] - 74s 47ms/step - loss: 0.6318 - accuracy: 0.7863 - val_loss: 0.5399 - val_accuracy: 0.8162
# Epoch 74/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.6321 - accuracy: 0.7844 - val_loss: 0.5521 - val_accuracy: 0.8107
# Epoch 75/100
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.6277 - accuracy: 0.7874 - val_loss: 0.5646 - val_accuracy: 0.8113
# Epoch 76/100
# 1563/1563 [==============================] - 527s 338ms/step - loss: 0.6256 - accuracy: 0.7863 - val_loss: 0.5055 - val_accuracy: 0.8296
# Epoch 77/100
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.6210 - accuracy: 0.7899 - val_loss: 0.5252 - val_accuracy: 0.8202
# Epoch 78/100
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.6138 - accuracy: 0.7905 - val_loss: 0.5381 - val_accuracy: 0.8187
# Epoch 79/100
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.6177 - accuracy: 0.7893 - val_loss: 0.5310 - val_accuracy: 0.8211
# Epoch 80/100
# 1563/1563 [==============================] - 74s 47ms/step - loss: 0.6138 - accuracy: 0.7921 - val_loss: 0.5301 - val_accuracy: 0.8219
# Epoch 81/100
# 1563/1563 [==============================] - 76s 49ms/step - loss: 0.6139 - accuracy: 0.7934 - val_loss: 0.5250 - val_accuracy: 0.8221
# Epoch 82/100
# 1563/1563 [==============================] - 90s 57ms/step - loss: 0.6108 - accuracy: 0.7917 - val_loss: 0.5043 - val_accuracy: 0.8301
# Epoch 83/100
# 1563/1563 [==============================] - 73s 47ms/step - loss: 0.6108 - accuracy: 0.7915 - val_loss: 0.5333 - val_accuracy: 0.8186
# Epoch 84/100
# 1563/1563 [==============================] - 76s 48ms/step - loss: 0.6056 - accuracy: 0.7937 - val_loss: 0.5582 - val_accuracy: 0.8134
# Epoch 85/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 0.6033 - accuracy: 0.7937 - val_loss: 0.5020 - val_accuracy: 0.8294
# Epoch 86/100
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.6045 - accuracy: 0.7943 - val_loss: 0.4973 - val_accuracy: 0.8305
# Epoch 87/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 0.6007 - accuracy: 0.7924 - val_loss: 0.4949 - val_accuracy: 0.8319
# Epoch 88/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 0.5976 - accuracy: 0.7959 - val_loss: 0.5985 - val_accuracy: 0.7963
# Epoch 89/100
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.5990 - accuracy: 0.7968 - val_loss: 0.4897 - val_accuracy: 0.8342
# Epoch 90/100
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.5894 - accuracy: 0.7980 - val_loss: 0.5374 - val_accuracy: 0.8191
# Epoch 91/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 0.5910 - accuracy: 0.7987 - val_loss: 0.5464 - val_accuracy: 0.8193
# Epoch 92/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 0.5934 - accuracy: 0.7993 - val_loss: 0.5050 - val_accuracy: 0.8306
# Epoch 93/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 0.5890 - accuracy: 0.7986 - val_loss: 0.4868 - val_accuracy: 0.8343
# Epoch 94/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 0.5877 - accuracy: 0.7994 - val_loss: 0.5100 - val_accuracy: 0.8248
# Epoch 95/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 0.5843 - accuracy: 0.8015 - val_loss: 0.5007 - val_accuracy: 0.8302
# Epoch 96/100
# 1563/1563 [==============================] - 68s 44ms/step - loss: 0.5846 - accuracy: 0.8006 - val_loss: 0.5177 - val_accuracy: 0.8230
# Epoch 97/100
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.5808 - accuracy: 0.8016 - val_loss: 0.5591 - val_accuracy: 0.8125
# Epoch 98/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 0.5788 - accuracy: 0.8037 - val_loss: 0.5320 - val_accuracy: 0.8214
# Epoch 99/100
# 1563/1563 [==============================] - 68s 43ms/step - loss: 0.5809 - accuracy: 0.8006 - val_loss: 0.5185 - val_accuracy: 0.8235
# Epoch 100/100
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.5770 - accuracy: 0.8042 - val_loss: 0.5970 - val_accuracy: 0.7946

# %% [markdown]
# # Evaluate the Model's Performance on the Test Set

# %%
scores = model.evaluate(test_x, test_y, verbose=1)
print("Test loss:", scores[0])
print("Test accuracy:", scores[1])
# Out:
# 313/313 [==============================] - 4s 12ms/step - loss: 0.5970 - accuracy: 0.7946
# Test loss: 0.5969820022583008
# Test accuracy: 0.7946000099182129

# %% [markdown]
# # Generate Predictions for Test Set

# %%
predictions = model.predict(test_x)
# Out:
# 313/313 [==============================] - 4s 13ms/step

# %% [markdown]
# # Generate a Confusion Matrix and Classification Report to Evaluate the Model's Performance

# %%
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(test_y, axis=1)
cm = confusion_matrix(true_classes, predicted_classes)
print("Confusion Matrix")
print(cm)
print("Classification Report")
print(classification_report(true_classes, predicted_classes, target_names=class_names))
# Out:
# Confusion Matrix
# [[820  23  14  15   7   2   6  15  32  66]
#  [  3 928   2   0   2   2   4   1   8  50]
#  [ 59   1 600  24  51  71 110  59   3  22]
#  [ 11   9  12 489  41 232  93  64   9  40]
#  [ 12   2  19  20 707  27 116  85   4   8]
#  [  5   3   9  40  22 804  35  64   6  12]
#  [  5   4  13  21   8  18 911  12   2   6]
#  [  7   5   0   7  13  20  11 924   0  13]
#  [ 60  30   2   5   0   4   6   1 826  66]
#  [  3  44   2   2   0   1   1   2   8 937]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Airplane       0.83      0.82      0.83      1000
#   Automobile       0.88      0.93      0.91      1000
#         Bird       0.89      0.60      0.72      1000
#          Cat       0.78      0.49      0.60      1000
#         Deer       0.83      0.71      0.76      1000
#          Dog       0.68      0.80      0.74      1000
#         Frog       0.70      0.91      0.79      1000
#        Horse       0.75      0.92      0.83      1000
#         Ship       0.92      0.83      0.87      1000
#        Truck       0.77      0.94      0.84      1000
#
#     accuracy                           0.79     10000
#    macro avg       0.81      0.79      0.79     10000
# weighted avg       0.81      0.79      0.79     10000

# %% [markdown]
# # Plot Training and Validation Accuracy and Loss to Visualize the Model's Learning Over Time

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="train accuracy")
plt.plot(history.history["val_accuracy"], label="validation accuracy")
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="train loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %% [markdown]
# # Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import (
    Dense,
    Flatten,
    Dropout,
    Conv2D,
    MaxPooling2D,
    BatchNormalization,
)
# from keras.optimizers import SGD
from tensorflow.compat.v1.keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %% [markdown]
# # Parameters for Model Training

# %%
batch_size = 32  # Number of samples per gradient update
num_classes = 10  # Total number of classes in the dataset
epochs = 100  # Number of epochs to train the model
data_augmentation = True  # Flag to determine whether to use data augmentation

# %% [markdown]
# # Load and Preprocess the CIFAR-10 Dataset

# %%
(train_x, train_y), (test_x, test_y) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 6s 0us/step

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_x[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_y[i][0]])
plt.show()

# %%
# Bar chart showing distribution of classes in training set
plt.figure(figsize=(11, 6))
unique, counts = np.unique(train_y, return_counts=True)

plt.bar(unique, counts)
plt.title('Class Frequency')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.xticks(unique, class_names)
plt.show()

# %% [markdown]
# # Preprocess the Data with One-Hot Encoding

# %%
# Convert class vectors to binary class matrices
train_y = to_categorical(train_y, num_classes)
test_y = to_categorical(test_y, num_classes)

# %%
# Normalize pixel values to the range [0, 1]to aid in training convergence
train_x = train_x.astype("float32") / 255.0
test_x = test_x.astype("float32") / 255.0

# %% [markdown]
# # Define the CNN model

# %%
def define_model():
    model = Sequential()
    # First convolutional block with 32 filters, batch normalization, and dropout for regularization
    model.add(
        Conv2D(
            32,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
            input_shape=(32, 32, 3),
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            32,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))

    # Second convolutional block with increased filter size for more complex feature extraction
    model.add(
        Conv2D(
            64,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(
        Conv2D(
            64,
            (3, 3),
            activation="relu",
            kernel_initializer="he_uniform",
            padding="same",
        )
    )
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))

    # Flatten the output from the convolutional layers before passing to the dense layer
    model.add(Flatten())
    # Dense layer for classification
    model.add(Dense(128, activation="relu", kernel_initializer="he_uniform"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    # Output layer with softmax activation for multi-class classification
    model.add(Dense(num_classes, activation="softmax"))

    # Compile the model with legacy SGD optimizer and categorical crossentropy loss function
    optimizer = SGD(learning_rate=0.01)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# # Instantiate and Compile the Model

# %%
model = define_model()

# %% [markdown]
# # Configure Data Augmentation

# %%
if data_augmentation:
    print("Using real-time data augmentation.")
    datagen = ImageDataGenerator(
        width_shift_range=0.1,  # Randomly shift images horizontally
        height_shift_range=0.1,  # Randomly shift images vertically
        horizontal_flip=True,  # Randomly flip images horizontally
    )
    # Compute quantities required for feature-wise normalization
    datagen.fit(train_x)
# Out:
# Using real-time data augmentation.

# %% [markdown]
# # Train the Model

# %%
if not data_augmentation:
    print("Not using data augmentation.")
    history = model.fit(
        train_x,
        train_y,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(test_x, test_y),
        shuffle=True,
    )
else:
    # Fit the model on the batches generated by datagen.flow()
    history = model.fit(
        datagen.flow(train_x, train_y, batch_size=batch_size),
        epochs=epochs,
        validation_data=(test_x, test_y),
        workers=4,
    )
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 49s 26ms/step - loss: 1.8519 - accuracy: 0.3658 - val_loss: 1.3617 - val_accuracy: 0.5025
# Epoch 2/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 1.4522 - accuracy: 0.4760 - val_loss: 1.2365 - val_accuracy: 0.5580
# Epoch 3/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.3345 - accuracy: 0.5225 - val_loss: 1.2172 - val_accuracy: 0.5587
# Epoch 4/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 1.2388 - accuracy: 0.5580 - val_loss: 1.0745 - val_accuracy: 0.6165
# Epoch 5/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 1.1794 - accuracy: 0.5811 - val_loss: 1.1172 - val_accuracy: 0.6029
# Epoch 6/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 1.1255 - accuracy: 0.6011 - val_loss: 0.9442 - val_accuracy: 0.6630
# Epoch 7/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 1.0908 - accuracy: 0.6159 - val_loss: 0.9943 - val_accuracy: 0.6469
# Epoch 8/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.0567 - accuracy: 0.6284 - val_loss: 0.9359 - val_accuracy: 0.6697
# Epoch 9/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.0336 - accuracy: 0.6361 - val_loss: 0.9451 - val_accuracy: 0.6639
# Epoch 10/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.0084 - accuracy: 0.6454 - val_loss: 0.9617 - val_accuracy: 0.6621
# Epoch 11/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.9849 - accuracy: 0.6555 - val_loss: 0.8919 - val_accuracy: 0.6851
# Epoch 12/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.9709 - accuracy: 0.6607 - val_loss: 0.8986 - val_accuracy: 0.6818
# Epoch 13/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.9510 - accuracy: 0.6678 - val_loss: 0.8472 - val_accuracy: 0.7033
# Epoch 14/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.9320 - accuracy: 0.6739 - val_loss: 0.8718 - val_accuracy: 0.6906
# Epoch 15/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.9178 - accuracy: 0.6824 - val_loss: 0.8024 - val_accuracy: 0.7167
# Epoch 16/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.9035 - accuracy: 0.6826 - val_loss: 0.8249 - val_accuracy: 0.7110
# Epoch 17/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.8926 - accuracy: 0.6877 - val_loss: 0.7619 - val_accuracy: 0.7320
# Epoch 18/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.8774 - accuracy: 0.6925 - val_loss: 0.7820 - val_accuracy: 0.7196
# Epoch 19/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.8634 - accuracy: 0.6982 - val_loss: 0.7878 - val_accuracy: 0.7202
# Epoch 20/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.8615 - accuracy: 0.6997 - val_loss: 0.7601 - val_accuracy: 0.7308
# Epoch 21/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.8516 - accuracy: 0.7033 - val_loss: 0.7706 - val_accuracy: 0.7290
# Epoch 22/100
# 1563/1563 [==============================] - 46s 29ms/step - loss: 0.8358 - accuracy: 0.7091 - val_loss: 0.8047 - val_accuracy: 0.7175
# Epoch 23/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.8278 - accuracy: 0.7130 - val_loss: 0.7919 - val_accuracy: 0.7203
# Epoch 24/100
# 1563/1563 [==============================] - 45s 29ms/step - loss: 0.8173 - accuracy: 0.7153 - val_loss: 0.7355 - val_accuracy: 0.7451
# Epoch 25/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.8077 - accuracy: 0.7193 - val_loss: 0.7244 - val_accuracy: 0.7463
# Epoch 26/100
# 1563/1563 [==============================] - 45s 28ms/step - loss: 0.8038 - accuracy: 0.7209 - val_loss: 0.7689 - val_accuracy: 0.7354
# Epoch 27/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.7955 - accuracy: 0.7224 - val_loss: 0.6829 - val_accuracy: 0.7611
# Epoch 28/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.7848 - accuracy: 0.7244 - val_loss: 0.7170 - val_accuracy: 0.7504
# Epoch 29/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.7786 - accuracy: 0.7294 - val_loss: 0.6983 - val_accuracy: 0.7586
# Epoch 30/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.7747 - accuracy: 0.7316 - val_loss: 0.7401 - val_accuracy: 0.7466
# Epoch 31/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.7642 - accuracy: 0.7334 - val_loss: 0.6829 - val_accuracy: 0.7571
# Epoch 32/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.7591 - accuracy: 0.7354 - val_loss: 0.7849 - val_accuracy: 0.7311
# Epoch 33/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.7593 - accuracy: 0.7352 - val_loss: 0.6812 - val_accuracy: 0.7603
# Epoch 34/100
# 1563/1563 [==============================] - 42s 26ms/step - loss: 0.7471 - accuracy: 0.7409 - val_loss: 0.6834 - val_accuracy: 0.7639
# Epoch 35/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.7434 - accuracy: 0.7414 - val_loss: 0.6633 - val_accuracy: 0.7711
# Epoch 36/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.7399 - accuracy: 0.7431 - val_loss: 0.6467 - val_accuracy: 0.7742
# Epoch 37/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.7298 - accuracy: 0.7454 - val_loss: 0.6603 - val_accuracy: 0.7705
# Epoch 38/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.7309 - accuracy: 0.7472 - val_loss: 0.7243 - val_accuracy: 0.7560
# Epoch 39/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.7201 - accuracy: 0.7515 - val_loss: 0.6640 - val_accuracy: 0.7686
# Epoch 40/100
# 1563/1563 [==============================] - 44s 28ms/step - loss: 0.7202 - accuracy: 0.7509 - val_loss: 0.6245 - val_accuracy: 0.7882
# Epoch 41/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.7107 - accuracy: 0.7560 - val_loss: 0.6487 - val_accuracy: 0.7746
# Epoch 42/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.7041 - accuracy: 0.7565 - val_loss: 0.6413 - val_accuracy: 0.7789
# Epoch 43/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.7044 - accuracy: 0.7572 - val_loss: 0.6692 - val_accuracy: 0.7701
# Epoch 44/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.7026 - accuracy: 0.7578 - val_loss: 0.7001 - val_accuracy: 0.7595
# Epoch 45/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.6956 - accuracy: 0.7582 - val_loss: 0.6168 - val_accuracy: 0.7877
# Epoch 46/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.6874 - accuracy: 0.7591 - val_loss: 0.6170 - val_accuracy: 0.7875
# Epoch 47/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.6896 - accuracy: 0.7615 - val_loss: 0.6166 - val_accuracy: 0.7889
# Epoch 48/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6824 - accuracy: 0.7663 - val_loss: 0.6980 - val_accuracy: 0.7603
# Epoch 49/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.6757 - accuracy: 0.7673 - val_loss: 0.5960 - val_accuracy: 0.7956
# Epoch 50/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6731 - accuracy: 0.7701 - val_loss: 0.6419 - val_accuracy: 0.7781
# Epoch 51/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.6759 - accuracy: 0.7659 - val_loss: 0.6162 - val_accuracy: 0.7908
# Epoch 52/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.6665 - accuracy: 0.7718 - val_loss: 0.5999 - val_accuracy: 0.7958
# Epoch 53/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6676 - accuracy: 0.7696 - val_loss: 0.5642 - val_accuracy: 0.8071
# Epoch 54/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.6588 - accuracy: 0.7732 - val_loss: 0.5829 - val_accuracy: 0.7991
# Epoch 55/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6563 - accuracy: 0.7740 - val_loss: 0.5834 - val_accuracy: 0.8021
# Epoch 56/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.6571 - accuracy: 0.7759 - val_loss: 0.5803 - val_accuracy: 0.8001
# Epoch 57/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.6518 - accuracy: 0.7766 - val_loss: 0.6155 - val_accuracy: 0.7896
# Epoch 58/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.6469 - accuracy: 0.7789 - val_loss: 0.5739 - val_accuracy: 0.8015
# Epoch 59/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.6438 - accuracy: 0.7788 - val_loss: 0.5773 - val_accuracy: 0.8031
# Epoch 60/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.6415 - accuracy: 0.7796 - val_loss: 0.6148 - val_accuracy: 0.7897
# Epoch 61/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6388 - accuracy: 0.7793 - val_loss: 0.6282 - val_accuracy: 0.7854
# Epoch 62/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6337 - accuracy: 0.7825 - val_loss: 0.6154 - val_accuracy: 0.7907
# Epoch 63/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.6341 - accuracy: 0.7828 - val_loss: 0.5877 - val_accuracy: 0.8012
# Epoch 64/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.6289 - accuracy: 0.7861 - val_loss: 0.5907 - val_accuracy: 0.8019
# Epoch 65/100
# 1563/1563 [==============================] - 43s 27ms/step - loss: 0.6263 - accuracy: 0.7826 - val_loss: 0.6039 - val_accuracy: 0.7962
# Epoch 66/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6283 - accuracy: 0.7828 - val_loss: 0.5716 - val_accuracy: 0.8031
# Epoch 67/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6197 - accuracy: 0.7873 - val_loss: 0.6228 - val_accuracy: 0.7898
# Epoch 68/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6166 - accuracy: 0.7883 - val_loss: 0.5328 - val_accuracy: 0.8191
# Epoch 69/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6156 - accuracy: 0.7888 - val_loss: 0.5403 - val_accuracy: 0.8158
# Epoch 70/100
# 1563/1563 [==============================] - 42s 27ms/step - loss: 0.6128 - accuracy: 0.7896 - val_loss: 0.5382 - val_accuracy: 0.8159
# Epoch 71/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.6192 - accuracy: 0.7888 - val_loss: 0.5435 - val_accuracy: 0.8146
# Epoch 72/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.6108 - accuracy: 0.7889 - val_loss: 0.5518 - val_accuracy: 0.8128
# Epoch 73/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.6108 - accuracy: 0.7908 - val_loss: 0.5460 - val_accuracy: 0.8166
# Epoch 74/100
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.5990 - accuracy: 0.7938 - val_loss: 0.5374 - val_accuracy: 0.8166
# Epoch 75/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5982 - accuracy: 0.7927 - val_loss: 0.5148 - val_accuracy: 0.8235
# Epoch 76/100
# 1563/1563 [==============================] - 45s 28ms/step - loss: 0.6031 - accuracy: 0.7918 - val_loss: 0.5536 - val_accuracy: 0.8108
# Epoch 77/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5990 - accuracy: 0.7960 - val_loss: 0.5600 - val_accuracy: 0.8138
# Epoch 78/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5924 - accuracy: 0.7958 - val_loss: 0.5701 - val_accuracy: 0.8086
# Epoch 79/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5935 - accuracy: 0.7931 - val_loss: 0.5275 - val_accuracy: 0.8196
# Epoch 80/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5874 - accuracy: 0.7984 - val_loss: 0.5460 - val_accuracy: 0.8117
# Epoch 81/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5860 - accuracy: 0.8000 - val_loss: 0.5620 - val_accuracy: 0.8110
# Epoch 82/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5874 - accuracy: 0.7987 - val_loss: 0.5362 - val_accuracy: 0.8186
# Epoch 83/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5763 - accuracy: 0.8014 - val_loss: 0.4955 - val_accuracy: 0.8307
# Epoch 84/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5837 - accuracy: 0.7999 - val_loss: 0.5624 - val_accuracy: 0.8081
# Epoch 85/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5853 - accuracy: 0.7998 - val_loss: 0.5448 - val_accuracy: 0.8125
# Epoch 86/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5778 - accuracy: 0.8025 - val_loss: 0.5079 - val_accuracy: 0.8279
# Epoch 87/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5830 - accuracy: 0.8004 - val_loss: 0.5260 - val_accuracy: 0.8195
# Epoch 88/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5750 - accuracy: 0.8027 - val_loss: 0.4970 - val_accuracy: 0.8303
# Epoch 89/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5718 - accuracy: 0.8016 - val_loss: 0.5053 - val_accuracy: 0.8266
# Epoch 90/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5726 - accuracy: 0.8047 - val_loss: 0.5499 - val_accuracy: 0.8129
# Epoch 91/100
# 1563/1563 [==============================] - 46s 30ms/step - loss: 0.5720 - accuracy: 0.8023 - val_loss: 0.5113 - val_accuracy: 0.8274
# Epoch 92/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5670 - accuracy: 0.8059 - val_loss: 0.5073 - val_accuracy: 0.8268
# Epoch 93/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5649 - accuracy: 0.8056 - val_loss: 0.5432 - val_accuracy: 0.8165
# Epoch 94/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5620 - accuracy: 0.8070 - val_loss: 0.5433 - val_accuracy: 0.8149
# Epoch 95/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5632 - accuracy: 0.8069 - val_loss: 0.5221 - val_accuracy: 0.8210
# Epoch 96/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5587 - accuracy: 0.8081 - val_loss: 0.5097 - val_accuracy: 0.8280
# Epoch 97/100
# 1563/1563 [==============================] - 41s 27ms/step - loss: 0.5562 - accuracy: 0.8091 - val_loss: 0.5255 - val_accuracy: 0.8239
# Epoch 98/100
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.5575 - accuracy: 0.8089 - val_loss: 0.4861 - val_accuracy: 0.8351
# Epoch 99/100
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.5634 - accuracy: 0.8069 - val_loss: 0.5101 - val_accuracy: 0.8262
# Epoch 100/100
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.5518 - accuracy: 0.8120 - val_loss: 0.5094 - val_accuracy: 0.8261

# %% [markdown]
# # Evaluate the Model's Performance on the Test Set

# %%
scores = model.evaluate(test_x, test_y, verbose=1)
print("Test loss:", scores[0])
print("Test accuracy:", scores[1])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5094 - accuracy: 0.8261
# Test loss: 0.5093774795532227
# Test accuracy: 0.8260999917984009

# %% [markdown]
# # Generate Predictions for Test Set

# %%
predictions = model.predict(test_x)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # Generate a Confusion Matrix and Classification Report to Evaluate the Model's Performance

# %%
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(test_y, axis=1)
cm = confusion_matrix(true_classes, predicted_classes)
print("Confusion Matrix")
print(cm)
print("Classification Report")
print(classification_report(true_classes, predicted_classes, target_names=class_names))
# Out:
# Confusion Matrix
# [[855  22  23   2   8   0   5   6  59  20]
#  [  7 945   0   0   2   0   2   0   4  40]
#  [ 54   3 705  15  66  25  89  26   6  11]
#  [ 16   9  43 548  71 116 119  33  20  25]
#  [ 11   1  29   8 837   7  68  29   7   3]
#  [ 11   2  35  75  45 712  55  48   6  11]
#  [  6   1  17   9  12   3 945   0   4   3]
#  [ 15   4  19   9  40   7  16 874   3  13]
#  [ 35  20   3   0   2   2   4   0 915  19]
#  [ 12  48   4   2   1   0   1   0   7 925]]
# Classification Report
#               precision    recall  f1-score   support
#
#     Airplane       0.84      0.85      0.85      1000
#   Automobile       0.90      0.94      0.92      1000
#         Bird       0.80      0.70      0.75      1000
#          Cat       0.82      0.55      0.66      1000
#         Deer       0.77      0.84      0.80      1000
#          Dog       0.82      0.71      0.76      1000
#         Frog       0.72      0.94      0.82      1000
#        Horse       0.86      0.87      0.87      1000
#         Ship       0.89      0.92      0.90      1000
#        Truck       0.86      0.93      0.89      1000
#
#     accuracy                           0.83     10000
#    macro avg       0.83      0.83      0.82     10000
# weighted avg       0.83      0.83      0.82     10000

# %% [markdown]
# # Plot Training and Validation Accuracy and Loss to Visualize the Model's Learning Over Time

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="train accuracy")
plt.plot(history.history["val_accuracy"], label="validation accuracy")
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="train loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.show()
